# %%
from src.utils.path_converter import path_converter

# %%
import pandas as pd
df = pd.read_csv(path_converter('/data/raw/sales_train.csv'))

# %%
print(df.head())
# Out:
#          date  date_block_num  shop_id  item_id  item_price  item_cnt_day
# 0  02.01.2013               0       59    22154      999.00           1.0
# 1  03.01.2013               0       25     2552      899.00           1.0
# 2  05.01.2013               0       25     2552      899.00          -1.0
# 3  06.01.2013               0       25     2554     1709.05           1.0
# 4  15.01.2013               0       25     2555     1099.00           1.0

# %% [markdown]
# Có 5 field
# - date: ngày.tháng.năm
# - date_block_num: khối thời gian vd: 0 tương đương với 01.01.2013 -> 31.01.2013
# - shop_id: id của shop
# - item_id: id sản phẩm
# - item_price: giá sản phẩm
# - item_cnt_day: số lượng bán được trong ngày

# %%
print(df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2935849 entries, 0 to 2935848
# Data columns (total 6 columns):
#  #   Column          Dtype
# ---  ------          -----
#  0   date            object
#  1   date_block_num  int64
#  2   shop_id         int64
#  3   item_id         int64
#  4   item_price      float64
#  5   item_cnt_day    float64
# dtypes: float64(2), int64(3), object(1)
# memory usage: 134.4+ MB
# None

# %%
print(df[["item_price", "item_cnt_day"]].describe())
# Out:
#          item_price  item_cnt_day
# count  2.935849e+06  2.935849e+06
# mean   8.908532e+02  1.242641e+00
# std    1.729800e+03  2.618834e+00
# min   -1.000000e+00 -2.200000e+01
# 25%    2.490000e+02  1.000000e+00
# 50%    3.990000e+02  1.000000e+00
# 75%    9.990000e+02  1.000000e+00
# max    3.079800e+05  2.169000e+03

# %% [markdown]
# - count: số lượng
# - mean: trung bình cộng
# - std: độ lệch chuẩn ( std lớn độ => range phân tán dữ liệu lớn, biến động lớn và ngược lại. )
# - min, max lần lượt là giá trị nhỏ nhất và lớn nhất.
# - phân vị 25%: giá trị mà 25% dữ liệu nhỏ hơn nó.
# - phân vị 50%: giá trị mà 50% dữ liệu nhỏ hơn nó.
# - phân vị 75%: giá trị mà 75% dữ liệu nhỏ hơn nó.

# %%
print(df.isnull().sum())
# Out:
# date              0
# date_block_num    0
# shop_id           0
# item_id           0
# item_price        0
# item_cnt_day      0
# dtype: int64

# %% [markdown]
# không có missing value
